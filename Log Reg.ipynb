# %%
import tarfile,sys
import pandas as pd
import os
import simplejson
 
def untar(fname):
    if (fname.endswith("tar") or fname.endswith("tgz") ):
        tar = tarfile.open(fname)
        tar.extractall()
        tar.close()
        print "Extracted in Current Directory"
    else:
        print "Not a tar.gz file: '%s '" % sys.argv[0]

# %%
untar('shared_task_data.tar')
# Out:
# Extracted in Current Directory

# %%
for i in range(1,2): 
    fpath='final_training_data/'+str(i)+'.tgz'
    untar(fpath)
# Out:
# Extracted in Current Directory

# %%
userInfo=pd.read_csv('anonymized_user_info_by_chunk.csv')

# %%
columns = ['class','user_name','tweet','avgsentiment', 'favorite_count', 'firstperson','geo','id','possibly_sensitive','retweet_count','retweeted','tsugawa']
data=pd.DataFrame(columns=columns)
for index, row in userInfo.iterrows():
    user=row['anonymized_screen_name']+'.tweets'
    if os.path.isfile(user): 
        print 'Reading file '+user
        try: 
            temp=pd.read_json(str(user), lines=True)
            add_first_person(temp)
            tsugawag(temp)
            avg_sentiment(temp)
            get_all_tweets(temp)
            temp['user_name'] = row['anonymized_screen_name']
            #temp['insomnia_index'] = (temp[temp.created_at.hour > 21].sum()-temp[temp.created_at.hour <= 21].sum())/temp.shape[0]
            temp['class'] = row['condition']
            final_temp = temp[columns]
            #print(temp[0])
            if data.empty:
                data=final_temp.loc[0:0]
            else:
                print("reached here")
                data = data.append(final_temp.loc[0:0])
        except:
            print "Bad File!"
# Out:
# Reading file p1oWIeRy95.tweets
# 1064.26092142
# 0.354753640472
# Reading file u6Q1cPYaegBS.tweets
# 118.556660476
# 0.155586168603
# reached here
# Reading file q5nbV1Dwkx3Uz8y.tweets
# Bad File!
# Reading file cpZb1zL.tweets
# 34.9936931067
# 0.08555915185
# reached here
# Reading file nC8trwq.tweets
# 278.282699199
# 0.0927608997331
# reached here
# Reading file mbKpnEfzJFe.tweets
# 344.904996417
# 0.114968332139
# reached here
# Reading file sdfBjrV9y.tweets
# Bad File!
# Reading file cMwx3Gi9RuskPTa.tweets
# 202.143428532
# 0.0941515736061
# reached here
# Reading file gnau5VYmZon.tweets
# 724.772792218
# 0.241590930739
# reached here
# Reading file w5zZbsisYcaA.tweets
# 192.546016189
# 0.201830205649
# reached here
# Reading file iBjhOmD.tweets
# 447.713145671
# 0.149237715224
# reached here
# Reading file q69HY7gQXtabz.tweets
# 502.975796395
# 0.167658598798
# reached here
# Reading file rHk1BCuEdYFyMB.tweets
# 274.205049695
# 0.0914016832316
# reached here
# Reading file ee7ABQXno.tweets
# 582.961258286
# 0.194320419429
# reached here
# Reading file g15QMjE.tweets
# Bad File!
# Reading file htBBgz9n8CLGzlp.tweets
# 356.688462186
# 0.118896154062
# reached here
# Reading file c_i5fdp13L.tweets
# 828.788868285
# 0.276262956095
# reached here
# Reading file kOjd8viHuHSdxwg.tweets
# 564.963164218
# 0.189457801549
# reached here
# Reading file pmbLyHCL.tweets
# 134.226618781
# 0.0447422062602
# reached here
# Reading file unI7OUqGI.tweets
# 88.9820580054
# 0.148799428103
# reached here

# %%
data
# Out:
#         class        user_name  \
# 0     control     u6Q1cPYaegBS
# 0     control          cpZb1zL
# 0  depression          nC8trwq
# 0     control      mbKpnEfzJFe
# 0     control  cMwx3Gi9RuskPTa
# 0  depression      gnau5VYmZon
# 0     control     w5zZbsisYcaA
# 0        ptsd          iBjhOmD
# 0     control    q69HY7gQXtabz
# 0        ptsd   rHk1BCuEdYFyMB
# 0     control        ee7ABQXno
# 0     control  htBBgz9n8CLGzlp
# 0  depression       c_i5fdp13L
# 0     control  kOjd8viHuHSdxwg
# 0  depression         pmbLyHCL
# 0     control        unI7OUqGI
#
#                                                tweet  avgsentiment  \
# 0                      Dinner wth my gals yeeeeyyy!!      0.155586
# 0         Ask me a question | http://t.co/H~dGIlbtRm      0.085559
# 0  RT @pvuoFh0N: Being a gentleman never goes out...      0.092761
# 0  RT @nT9KP4M4GGud: An intelligent man is so att...      0.114968
# 0  RT @ewczqMHQWKora: Wash the dirt off and shine...      0.094152
# 0       @mSU4tZcqIw70Bk praying for her safe return!      0.241591
# 0  Today stats: One follower, No unfollowers via ...      0.201830
# 0  RT @g2zLMrKgT8FHn: Today is the day! lowest ra...      0.149238
# 0  #MondayBlogs You Owe It To Your Readers To Be ...      0.167659
# 0  http://t.co/G0OJT4-e1M     Thank you everyone ...      0.091402
# 0  #OLD @sdIiUC9V2mOoF @lAgyPMcDsKmFq &amp; #MO A...      0.194320
# 0  Mentor with the pic then the half back pass fo...      0.118896
# 0  @lSOkeUyKKtAOK I love you so much! You were th...      0.276263
# 0  RT @qmCvONVzprk: Our baby girl is 6 months old...      0.189458
# 0  RT @itKnzeCETI2: 寝れなくてネットサーフィンしてたら、ヤバイコスプレイヤー見...      0.044742
# 0  @npj9Xk If Sanchez and Romo can be a starter t...      0.148799
#
#    favorite_count  firstperson  geo                   id  possibly_sensitive  \
# 0               0          645  NaN  3270683617599762436                 NaN
# 0               0          367  NaN  5787167597109857946                 0.0
# 0               0         2222  NaN  4258046557791254797                 NaN
# 0               0         2431  NaN  9036456942659112671                 NaN
# 0               0         1835  NaN  2135526198652413743                 NaN
# 0               1         2620  NaN  9109593059979792776                 NaN
# 0               0          659  NaN  5554764028281426930                 0.0
# 0               0         2554  NaN  1008160895688102822                 0.0
# 0               3         2697  NaN  5692898157399754606                 0.0
# 0               0         1550  NaN  5429583478395138576                 0.0
# 0               0         2156  NaN   344371067015090034                 0.0
# 0               0         2402  NaN  5309807517217416549                 NaN
# 0               0         2746  NaN  4919103942285707264                 NaN
# 0               0         2674  NaN  4432766568070549267                 NaN
# 0               0         2328  NaN  3866288179773398935                 0.0
# 0               0          510  NaN  6323074058246511600                 NaN
#
#    retweet_count  retweeted  tsugawa
# 0              0      False        0
# 0              0      False        0
# 0            210      False        0
# 0              3      False        0
# 0              3      False        0
# 0              0      False        0
# 0              0      False        0
# 0              3      False        0
# 0              9      False        0
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0           7802      False        0
# 0           4603      False        0
# 0              0      False        0

# %%
# entities=data.entities.apply(pd.Series)
# screen_name_stats=data.screen_name_statistics.apply(pd.Series)
# user =data.user.apply(pd.Series)

# %%
## Some trouble with this
#temp['insomnia_index'] = (temp[temp.created_at.hour > 21].sum()-temp[temp.created_at.hour <= 21].sum())/temp.shape[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7ada240800e9> in <module>()
# ----> 1 temp['insomnia_index'] = (temp[temp.created_at.hour > 21].sum()-temp[temp.created_at.hour <= 21].sum())/temp.shape[0]
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'hour'

# %%
# final_data = data[['class','user_name','tweet','avgsentiment', 'favorite_count', 'firstperson','geo','id','possibly_sensitive','retweet_count','retweeted','tsugawa']]
# #data[data['user_name'] == 'mbKpnEfzJFe']
# final_data.shape
# Out:
# (204,)

# %%
# x = data[data['user_name'] == 'mbKpnEfzJFe']["tweet"]
# x.astype(str)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-101-01d693d0471c> in <module>()
#       1 x = data[data['user_name'] == 'mbKpnEfzJFe']["tweet"]
# ----> 2 x.astype(str)
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# /home/kripa/.local/lib/python2.7/site-packages/pandas/core/dtypes/cast.pyc in astype_nansafe(arr, dtype, copy)
#     648         return lib.astype_unicode(arr.ravel()).reshape(arr.shape)
#     649     elif issubclass(dtype.type, string_types):
# --> 650         return lib.astype_str(arr.ravel()).reshape(arr.shape)
#     651     elif is_datetime64_dtype(arr):
#     652         if dtype == object:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_str()
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_str()
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\U0001f60d' in position 54: ordinal not in range(128)

# %%
#insomnia index 
#temp=pd.read_json('mbKpnEfzJFe.tweets', lines=True)
#temp['insomnia_index'] = ( (pd.to_datetime(temp["created_at"]).dt.hour > 21).sum() - (pd.to_datetime(temp["created_at"]).dt.hour <= 21).sum() )/temp.shape[0]

# %%
def add_first_person(temp):
    import numpy as np
    #first person 
    first =  ["i", "i'd", "i'll", "i'm", "i've", "me", "my"]
    temp['firstperson'] =temp['text'].str.lower().str.split()
    count_fp = 0
    for i in temp['text']:
        count_fp += len(set(i) & set(first))
    temp['firstperson'] = count_fp

# %%
#print(temp.loc[0:0])
# Out:
#            created_at                                           entities  \
# 0 2013-11-22 07:05:30  {u'symbols': [], u'user_mentions': [{u'indices...
#
#    favorite_count  geo                   id               id_str  \
# 0               0  NaN  9036456942659112671  9036456942659112960
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
#
#    in_reply_to_user_id                        ...                          \
# 0                  NaN                        ...
#
#    lang place  possibly_sensitive  retweet_count  retweeted  \
# 0    en   NaN                 NaN              3      False
#
#                                     retweeted_status  \
# 0  {u'lang': u'en', u'created_at': u'Fri Nov 22 0...
#
#                               screen_name_statistics  \
# 0  {u'has_underscore': False, u'contains_swear': ...
#
#                                                 text truncated  \
# 0  RT @nT9KP4M4GGud: An intelligent man is so att...     False
#
#                                                 user
# 0  {u'lang': u'en', u'utc_offset': None, u'status...
#
# [1 rows x 21 columns]

# %%
#tsugawa_terms 
def tsugawag(temp):
    tsugawa_terms = ["even if", "low fever", "very", "workplace", "hopeless", "disappear", "too much", "sickness", "bad", "hospital"]
    temp_words =temp['text'].str.lower().str.split()
    count_tsugawa = 0
    for i in temp['text']:
        count_tsugawa += len(set(i) & set(tsugawa_terms))
    count_final = count_tsugawa/len(temp["text"])
    temp['tsugawa'] = count_final

# %%
def avg_sentiment(temp):
    from textblob import TextBlob
    avg = 0
    for i in temp['text']:
        blob = TextBlob(i)
        sentiment = blob.sentiment.polarity
        avg += sentiment
    print(avg)
    avg_sentiment = avg / len(temp['text'])
    print(avg_sentiment)
    temp['avgsentiment'] = avg_sentiment

# %%
def get_all_tweets(temp):
    all_text = ""
    for i in temp['text']:
        all_text+=i
    temp['tweet'] = all_text
    #print(all_text)

# %%
# get_all_tweets(temp)
# print(temp.loc[0:0]["tweet"])
# Out:
# 0    RT @nT9KP4M4GGud: An intelligent man is so att...
# Name: tweet, dtype: object

# %%
def remove_by_regex(tweets, regexp):
    tweets.loc[:, "tweet"].replace(regexp, "", inplace=True)
    return tweets

def remove_urls(tweets):
    return remove_by_regex(tweets, regex.compile(r"http.?://[^\s]+[\s]?"))

def remove_na(tweets):
    return tweets[tweets["tweet"] != "Not Available"]

def remove_special_chars(tweets):  # it unrolls the hashtags to normal words
    for remove in map(lambda r: regex.compile(regex.escape(r)), [",", ":", "\"", "=", "&", ";", "%", "$",
                                                                 "@", "%", "^", "*", "(", ")", "{", "}",
                                                                 "[", "]", "|", "/", "\\", ">", "<", "-",
                                                                 "!", "?", ".", "'",
                                                                 "--", "---", "#"]):
        tweets.loc[:, "tweet"].replace(remove, "", inplace=True)
    return tweets

def remove_usernames(tweets):
    return remove_by_regex(tweets, regex.compile(r"@[^\s]+[\s]?"))

def remove_numbers(tweets):
    return remove_by_regex(tweets, regex.compile(r"\s?[0-9]+\.?[0-9]*"))

# %%
import re as regex
data = data
data = remove_urls(data)
data = remove_na(data)
data = remove_special_chars(data)
data = remove_usernames(data)
data = remove_numbers(data)
#data.cleanup(TwitterCleanuper())
data.head(5)
# Out:
#         class     user_name  \
# 0  depression    p1oWIeRy95
# 0     control  u6Q1cPYaegBS
# 0     control       cpZb1zL
# 0  depression       nC8trwq
# 0     control   mbKpnEfzJFe
#
#                                                tweet  avgsentiment  \
# 0  baLKoKrkpq goodnight chicken strip i love you ...      0.354754
# 0  Dinner wth my gals yeeeeyyykPctsovdlz jxXTU ha...      0.155586
# 0  Ask me a question  are you wearing right now —...      0.085559
# 0  RT pvuoFhN Being a gentleman never goes out of...      0.092761
# 0  RT nTKPMGGud An intelligent man is so attracti...      0.114968
#
#    favorite_count  firstperson  geo                   id  possibly_sensitive  \
# 0               1         2227  NaN  3858261610217213963                 NaN
# 0               0          645  NaN  3270683617599762436                 NaN
# 0               0          367  NaN  5787167597109857946                 0.0
# 0               0         2222  NaN  4258046557791254797                 NaN
# 0               0         2431  NaN  9036456942659112671                 NaN
#
#    retweet_count  retweeted  tsugawa
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0            210      False        0
# 0              3      False        0

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
def clean_data(ingredients):
    lmtzr = WordNetLemmatizer()
    def split_word(strOfWords):
        #print(strOfWords)
        tempWords  = []
        toRemove  = []
        for word in strOfWords.split():
            word = "".join(x for x in word if x.isalpha())
            word = "".join(lmtzr.lemmatize(word))
            if word.lower() not in toRemove:
                 tempWords.append(word)
        return tempWords
    return [split_word(y) for y in ingredients]

# %%
data["tweet"]= clean_data(data["tweet"])

# %%
data["total_words"] = data["tweet"].map(",".join)
data["total_words"] = data["total_words"].str.strip()

# %%
data.fillna(0)
# Out:
#         class        user_name  \
# 0  depression       p1oWIeRy95
# 0     control     u6Q1cPYaegBS
# 0     control          cpZb1zL
# 0  depression          nC8trwq
# 0     control      mbKpnEfzJFe
# 0     control  cMwx3Gi9RuskPTa
# 0  depression      gnau5VYmZon
# 0     control     w5zZbsisYcaA
# 0        ptsd          iBjhOmD
# 0     control    q69HY7gQXtabz
# 0        ptsd   rHk1BCuEdYFyMB
# 0     control        ee7ABQXno
# 0     control  htBBgz9n8CLGzlp
# 0  depression       c_i5fdp13L
# 0     control  kOjd8viHuHSdxwg
# 0  depression         pmbLyHCL
# 0     control        unI7OUqGI
#
#                                                tweet  avgsentiment  \
# 0  [baLKoKrkpq, goodnight, chicken, strip, i, lov...      0.354754
# 0  [Dinner, wth, my, gal, yeeeeyyykPctsovdlz, jxX...      0.155586
# 0  [Ask, me, a, question, are, you, wearing, righ...      0.085559
# 0  [RT, pvuoFhN, Being, a, gentleman, never, go, ...      0.092761
# 0  [RT, nTKPMGGud, An, intelligent, man, is, so, ...      0.114968
# 0  [RT, ewczqMHQWKora, Wash, the, dirt, off, and,...      0.094152
# 0  [mSUtZcqIwBk, praying, for, her, safe, returnR...      0.241591
# 0  [Today, stats, One, follower, No, unfollowers,...      0.201830
# 0  [RT, gzLMrKgTFHn, Today, is, the, day, lowest,...      0.149238
# 0  [MondayBlogs, You, Owe, It, To, Your, Readers,...      0.167659
# 0  [Thank, you, everyone, who, ha, like, or, shar...      0.091402
# 0  [OLD, sdIiUCVmOoF, lAgyPMcDsKmFq, amp, MO, AT,...      0.194320
# 0  [Mentor, with, the, pic, then, the, half, back...      0.118896
# 0  [lSOkeUyKKtAOK, I, love, you, so, much, You, w...      0.276263
# 0  [RT, qmCvONVzprk, Our, baby, girl, is, month, ...      0.189458
# 0  [RT, itKnzeCETI, 寝れなくてネットサーフィンしてたらヤバイコスプレイヤー見つ...      0.044742
# 0  [npjXk, If, Sanchez, and, Romo, can, be, a, st...      0.148799
#
#    favorite_count  firstperson  geo                   id  possibly_sensitive  \
# 0               1         2227  0.0  3858261610217213963                 0.0
# 0               0          645  0.0  3270683617599762436                 0.0
# 0               0          367  0.0  5787167597109857946                 0.0
# 0               0         2222  0.0  4258046557791254797                 0.0
# 0               0         2431  0.0  9036456942659112671                 0.0
# 0               0         1835  0.0  2135526198652413743                 0.0
# 0               1         2620  0.0  9109593059979792776                 0.0
# 0               0          659  0.0  5554764028281426930                 0.0
# 0               0         2554  0.0  1008160895688102822                 0.0
# 0               3         2697  0.0  5692898157399754606                 0.0
# 0               0         1550  0.0  5429583478395138576                 0.0
# 0               0         2156  0.0   344371067015090034                 0.0
# 0               0         2402  0.0  5309807517217416549                 0.0
# 0               0         2746  0.0  4919103942285707264                 0.0
# 0               0         2674  0.0  4432766568070549267                 0.0
# 0               0         2328  0.0  3866288179773398935                 0.0
# 0               0          510  0.0  6323074058246511600                 0.0
#
#    retweet_count  retweeted  tsugawa  \
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0            210      False        0
# 0              3      False        0
# 0              3      False        0
# 0              0      False        0
# 0              0      False        0
# 0              3      False        0
# 0              9      False        0
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0              0      False        0
# 0           7802      False        0
# 0           4603      False        0
# 0              0      False        0
#
#                                          total_words
# 0  baLKoKrkpq,goodnight,chicken,strip,i,love,you,...
# 0  Dinner,wth,my,gal,yeeeeyyykPctsovdlz,jxXTU,hah...
# 0  Ask,me,a,question,are,you,wearing,right,now,,M...
# 0  RT,pvuoFhN,Being,a,gentleman,never,go,out,of,s...
# 0  RT,nTKPMGGud,An,intelligent,man,is,so,attracti...
# 0  RT,ewczqMHQWKora,Wash,the,dirt,off,and,shine,o...
# 0  mSUtZcqIwBk,praying,for,her,safe,returnRT,mSUt...
# 0  Today,stats,One,follower,No,unfollowers,via,st...
# 0  RT,gzLMrKgTFHn,Today,is,the,day,lowest,rate,fo...
# 0  MondayBlogs,You,Owe,It,To,Your,Readers,To,Be,I...
# 0  Thank,you,everyone,who,ha,like,or,shared,on,Go...
# 0  OLD,sdIiUCVmOoF,lAgyPMcDsKmFq,amp,MO,AT,POOH,a...
# 0  Mentor,with,the,pic,then,the,half,back,pas,for...
# 0  lSOkeUyKKtAOK,I,love,you,so,much,You,were,the,...
# 0  RT,qmCvONVzprk,Our,baby,girl,is,month,old,toda...
# 0  RT,itKnzeCETI,寝れなくてネットサーフィンしてたらヤバイコスプレイヤー見つけたｗ...
# 0  npjXk,If,Sanchez,and,Romo,can,be,a,starter,thi...

# %%
def wordTokenizer(text):
    return text.split(",")
#Use count vectorizer to create X = n*d where n = number of samples, d=dishes. 
cv = CountVectorizer(stop_words="english",lowercase=True,tokenizer=wordTokenizer,token_pattern="[A-Za-z]*",strip_accents='ascii',vocabulary=None)
X = cv.fit_transform(data["total_words"].values)
print("Unique ingredients after data cleaning: ", X.shape[1])
# Out:
# ('Unique ingredients after data cleaning: ', 48155)

# %%
from scipy.sparse import csr_matrix
import scipy.sparse as sparse
t = data.iloc[:,3:6]
t = sparse.csr_matrix(t)
print(t.shape)
X_new = sparse.hstack((X,t))
print(X_new.shape)
# Out:
# (17, 3)
# (17, 48158)

# %%
from sklearn.preprocessing import LabelEncoder
cuisineEncoder = LabelEncoder()
y = cuisineEncoder.fit_transform(data['class'])
from sklearn.linear_model import LogisticRegression
log = cross_val_score(LogisticRegression(), X_new, y,cv=3)
print("Logisitic regression average accuracy : ",log.mean())
# Out:
# ('Logisitic regression average accuracy : ', 0.4761904761904762)
